# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("C:/Users/HARSHA/Downloads/Company_Data (1).csv")

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
# Sales          400 non-null float64
# CompPrice      400 non-null int64
# Income         400 non-null int64
# Advertising    400 non-null int64
# Population     400 non-null int64
# Price          400 non-null int64
# ShelveLoc      400 non-null object
# Age            400 non-null int64
# Education      400 non-null int64
# Urban          400 non-null object
# US             400 non-null object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
df.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
sns.lmplot(x='Income', y='Sales', data=df)

# %%
sns.pairplot(df)

# %%
df[df.duplicated()].shape
# Out:
# (0, 11)

# %%
df['Sales'] = pd.cut(df.Sales,bins=(0,7.49,16.27),labels=['lowsales','highsales'])
df
# Out:
#          Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  \
# 0    highsales        138      73           11         276    120       Bad
# 1    highsales        111      48           16         260     83      Good
# 2    highsales        113      35           10         269     80    Medium
# 3     lowsales        117     100            4         466     97    Medium
# 4     lowsales        141      64            3         340    128       Bad
# ..         ...        ...     ...          ...         ...    ...       ...
# 395  highsales        138     108           17         203    128      Good
# 396   lowsales        139      23            3          37    120    Medium
# 397   lowsales        162      26           12         368    159    Medium
# 398   lowsales        100      79            7         284     95       Bad
# 399  highsales        134      37            0          27    120      Good
#
#      Age  Education Urban   US
# 0     42         17   Yes  Yes
# 1     65         10   Yes  Yes
# 2     59         12   Yes  Yes
# 3     55         14   Yes  Yes
# 4     38         13   Yes   No
# ..   ...        ...   ...  ...
# 395   33         14   Yes  Yes
# 396   55         11    No  Yes
# 397   40         18   Yes  Yes
# 398   50         12   Yes  Yes
# 399   49         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
df=df.drop(df.index[[174]],axis=0).reset_index()
df
# Out:
#      index      Sales  CompPrice  Income  Advertising  Population  Price  \
# 0        0  highsales        138      73           11         276    120
# 1        1  highsales        111      48           16         260     83
# 2        2  highsales        113      35           10         269     80
# 3        3   lowsales        117     100            4         466     97
# 4        4   lowsales        141      64            3         340    128
# ..     ...        ...        ...     ...          ...         ...    ...
# 394    395  highsales        138     108           17         203    128
# 395    396   lowsales        139      23            3          37    120
# 396    397   lowsales        162      26           12         368    159
# 397    398   lowsales        100      79            7         284     95
# 398    399  highsales        134      37            0          27    120
#
#     ShelveLoc  Age  Education Urban   US
# 0         Bad   42         17   Yes  Yes
# 1        Good   65         10   Yes  Yes
# 2      Medium   59         12   Yes  Yes
# 3      Medium   55         14   Yes  Yes
# 4         Bad   38         13   Yes   No
# ..        ...  ...        ...   ...  ...
# 394      Good   33         14   Yes  Yes
# 395    Medium   55         11    No  Yes
# 396    Medium   40         18   Yes  Yes
# 397       Bad   50         12   Yes  Yes
# 398      Good   49         16   Yes  Yes
#
# [399 rows x 12 columns]

# %%
df=df.drop(['index'],axis=1)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
label_encoder_x=LabelEncoder()
x=x.apply(LabelEncoder().fit_transform)

# %%
x.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0      0         49      51           11         141     54          0   17
# 1      0         22      27           16         129     18          1   40
# 2      0         24      14           10         138     15          2   34
# 3      1         28      77            4         249     31          2   30
# 4      1         52      42            3         178     62          0   13
#
#    Education  Urban
# 0          7      1
# 1          0      1
# 2          2      1
# 3          4      1
# 4          3      1

# %%
x.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
rf = RandomForestClassifier(n_jobs=3,oob_score=True,n_estimators=100,criterion="entropy")
rf
# Out:
# RandomForestClassifier(criterion='entropy', n_jobs=3, oob_score=True)

# %%
rf.fit(x,y)
# Out:
# RandomForestClassifier(criterion='entropy', n_jobs=3, oob_score=True)

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1081440597),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1850361360),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1561472094),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=2089629533),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=751952373),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1525224578),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1332734535),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=609433542),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1912692193),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1291152384),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1655620808),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1422700532),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=787097848),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=687092568),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=972569902),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1470948463),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=369250430),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=352062163),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1100441385),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=481761257),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1915254723),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1122324237),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=134227290),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1944875619),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=746400258),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=644327668),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1426024592),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=795988780),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=166688823),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=634484626),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=681522040),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=830328942),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=2116663631),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=449594518),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=298122654),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=628431663),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=766504303),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=553345334),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=2043505228),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=395756977),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1183476861),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1624698653),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=829979325),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1494551526),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1735277575),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1388748872),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=802861737),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1274259999),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1950250453),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1778148349),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1154045482),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1388617195),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=528882733),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1470671397),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1993628408),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=2071625097),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=124087818),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=287701669),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=561477138),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1463038224),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1775270051),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1171066344),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1911488437),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1750489498),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1970381256),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1366419391),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1216164620),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=80036181),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1001259507),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=814851395),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=874238716),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=160688653),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=384372921),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1199864933),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1119307439),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=526270806),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1442422137),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=161481031),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=229959092),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1177361261),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1844516304),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=503123865),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=307671675),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=133711666),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1630684214),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=450871051),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1312359230),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=747139393),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1285679728),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=267893734),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1918825065),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1999326104),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1104173064),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=226821364),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=2147363002),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=360612116),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1105145164),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=646201985),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=865131577),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1330766994)]

# %%
rf.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
rf.n_outputs_
# Out:
# 1

# %%
rf.n_features_
# Out:
# 10

# %%
rf.oob_score_
# Out:
# 0.9122807017543859

# %%
rf.predict(x)
# Out:
# array(['Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'No',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No',
#        'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No',
#        'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No',
#        'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'No',
#        'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No',
#        'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes',
#        'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes'], dtype=object)

# %%
df['rf_pred'] = rf.predict(x)

# %%
cols = ['rf_pred','Sales']
cols
# Out:
# ['rf_pred', 'Sales']

# %%
df[cols].head()
# Out:
#   rf_pred      Sales
# 0     Yes  highsales
# 1     Yes  highsales
# 2     Yes  highsales
# 3     Yes   lowsales
# 4      No   lowsales

# %%
df['Sales']
# Out:
# 0      highsales
# 1      highsales
# 2      highsales
# 3       lowsales
# 4       lowsales
#          ...
# 394    highsales
# 395     lowsales
# 396     lowsales
# 397     lowsales
# 398    highsales
# Name: Sales, Length: 399, dtype: category
# Categories (2, object): [lowsales < highsales]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(df['Sales'],df['rf_pred'])
# Out:
# array([[  0,   0,   0,   0],
#        [  0,   0,   0,   0],
#        [ 57, 142,   0,   0],
#        [ 84, 116,   0,   0]], dtype=int64)

# %%
pd.crosstab(df['Sales'],df['rf_pred'])
# Out:
# rf_pred    No  Yes
# Sales
# lowsales   84  116
# highsales  57  142
